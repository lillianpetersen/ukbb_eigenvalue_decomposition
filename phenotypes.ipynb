# %%
import hail as hl

from hail.plot import show
from os import path
import os
import pandas as pd
import scipy.linalg
import numpy as np

hl.plot.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
#Useful command to specify nuimber of partitions:
def read_with_partitions(path, n_parts):
     mt = hl.read_matrix_table(path)
     return hl.read_matrix_table(path, _intervals=mt._calculate_new_partitions(n_parts))

# %%
# Set parameters
pct = 1
print(str(pct)+"pct")
# Out:
# 1pct

# %%
#Specify file names and locations:
genomt_file = "gs://ukb31063/ukb31063.genotype.mt"

withdrawn_file = "gs://ukb31063/ukb31063.withdrawn_samples.ht"
gwassamples_file ="gs://ukb31063/ukb31063.neale_gwas_samples.both_sexes.ht"
sampleqc_file = "gs://ukb31063/ukb31063.sample_qc.tsv.bgz"
snpqc_file = "gs://ukb-gt/ukb_snp_qc_forHail_chr1to22.txt"

gwasvariants_file = "gs://ukb31063/ukb31063.neale_gwas_variants.ht"

phenos_file = "gs://ukb31063/ukb31063.PHESANT_January_2019.both_sexes.tsv.bgz"
assessment_file = "gs://ukb-gt/ukb_acentre.csv"
covariates_file = "gs://ukb31063/ukb31063.neale_gwas_covariates.both_sexes.tsv.bgz"

pcvar_file = "gs://nbaya/sex_linreg/ukb31063.*_phenotypes.both_sexes.reg1.tsv.bgz"

# phenotype_file = "gs://nbaya/sex_linreg/ukb31063.*_phenotypes.both_sexes.reg1.tsv.bgz"

# %%
# Define phenotype and assessment centre classification:
pcvar = hl.import_table(pcvar_file)
# Out:
# 2021-02-19 15:03:26 Hail: INFO: Loading 45 fields. Counts by type:
#   str: 45

# %%
pcvar.describe()
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Row fields:
#     'phen': str
#     'r2_mul': str
#     'r2_adj': str
#     'beta_intercept': str
#     'beta_PC1': str
#     'beta_PC2': str
#     'beta_PC3': str
#     'beta_PC4': str
#     'beta_PC5': str
#     'beta_PC6': str
#     'beta_PC7': str
#     'beta_PC8': str
#     'beta_PC9': str
#     'beta_PC10': str
#     'beta_PC11': str
#     'beta_PC12': str
#     'beta_PC13': str
#     'beta_PC14': str
#     'beta_PC15': str
#     'beta_PC16': str
#     'beta_PC17': str
#     'beta_PC18': str
#     'beta_PC19': str
#     'beta_PC20': str
#     'se_intercept': str
#     'se_PC1': str
#     'se_PC2': str
#     'se_PC3': str
#     'se_PC4': str
#     'se_PC5': str
#     'se_PC6': str
#     'se_PC7': str
#     'se_PC8': str
#     'se_PC9': str
#     'se_PC10': str
#     'se_PC11': str
#     'se_PC12': str
#     'se_PC13': str
#     'se_PC14': str
#     'se_PC15': str
#     'se_PC16': str
#     'se_PC17': str
#     'se_PC18': str
#     'se_PC19': str
#     'se_PC20': str
# ----------------------------------------
# Key: []
# ----------------------------------------

# %%
pcvar_df = pcvar.to_pandas()

# %%
import csv
path = '/tmp/pcvar.tsv'
pcvar_df.to_csv(path, sep='\t', index=False, quoting=csv.QUOTE_NONE)
hl.hadoop_copy('file:///tmp/pcvar.tsv', 'gs://ukb-gt/pcvar.tsv')

# %%
pcvar_df.head(20)['phen']
# Out:
# 0         ICDMAIN_ANY_ENTRY
# 1              XI_DIGESTIVE
# 2        XVIII_MISCFINDINGS
# 3        XIII_MUSCULOSKELET
# 4         XIV_GENITOURINARY
# 5               II_NEOPLASM
# 6            IX_CIRCULATORY
# 7         XXI_HEALTHFACTORS
# 8         XIX_INJURY_POISON
# 9            VII_EYE_ADNEXA
# 10           M13_OTHERJOINT
# 11        XII_SKIN_SUBCUTAN
# 12              ILD_DIFF_DG
# 13                COPD_EXCL
# 14               K11_HERNIA
# 15              PULMONARYDG
# 16            X_RESPIRATORY
# 17            M13_ARTHROSIS
# 18    PULM_MEDICATIO_COMORB
# 19               VI_NERVOUS
# Name: phen, dtype: object
